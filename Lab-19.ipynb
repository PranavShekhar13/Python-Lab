# %% [markdown]
# # Lab 19 - 1828258 Pranav Shekhar

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
data= sns.load_dataset("iris")
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.regplot(x="sepal_length",y="petal_length", data=data)

# %%
sns.regplot(x="petal_width",y="sepal_length", data=data)

# %%
sns.relplot(x="petal_width",y="sepal_length", data=data, kind="line")

# %%
sns.catplot(x="species", data=data)

# %%
sns.catplot(x="species",y="sepal_length", kind="violin", data=data)

# %%
from scipy import stats

data = np.random.normal(loc=5, size=100, scale=2)

# %%
sns.distplot(data)

# %%
data2= sns.load_dataset("titanic")
data2 = np.random.normal(loc=5, size=100, scale=2)

with sns.axes_style("white"):
    sns.jointplot(x=data, y=data2, kind="kde", color="b")

# %% [markdown]
# ## Extract the Titanic Dataset and perform the following operations.

# %% [markdown]
# ## 1. Count the number of  data column wise

# %%
data3 = pd.read_csv('titanic.csv')

data3.count(axis=1)
# Out:
# 0      11
# 1      12
# 2      11
# 3      12
# 4      11
#        ..
# 886    11
# 887    12
# 888    10
# 889    12
# 890    11
# Length: 891, dtype: int64

# %% [markdown]
# ## 2. Draw a histogram basis on fare

# %%
fare = data3['Fare']

fare.hist(bins=50, color='red', figsize=(10,7) )

# %% [markdown]
# ## 3. Use boxplot function taking class and age

# %%
sns.boxplot(data=data3, x='Pclass' , y='Age')

# %% [markdown]
#  ## 4. Use swarmplot  taking class and age

# %%
sns.swarmplot(data=data3, x="Pclass", y="Age")
